# %%
import numpy as np
import pandas as pd
from IPython.display import display

# %% [markdown]
# ## **EU CORDIS DATAPREPROCESSING**
# This notebook transforms a specified EU cordis folder inputs into a preprocessed .pkl file. The final .pkl file will contain only NL projects filtered by whether any of the associated organizations contain a Dutch vatNumber.

# %% [markdown]
# ## **TABLE OF CONTENTS**:
# - [HOW TO USE](#1)
# - [SELECT DATA](#2)
# - [MERGE DATA AND FILTER ON NL](#3)
# - [PREPROCESSING](#4)
# - [EXPORT TO PKL](#5)

# %% [markdown]
# ## **HOW TO USE**
# 1. Ensure the input files organization.csv and project.csv are downloaded by eu_dataloader.ipynb.
# 2. Select the folder name in the cell below.
# 3. Run the entire notebook to produce a .pkl file.

# %% [markdown]
# ## **SELECT DATA** <a class="anchor" id="2"></a>

# %%
# Choose one of the below options (note that this project should already have been downloaded with Cordis EU dataloader) :
# eu_cordis_2007_2013
# eu_cordis_2014_2020
# eu_cordis_2021_2027

EU_CORDIS_PROJECT_NAME = 'eu_cordis_2007_2013' 


df_organization = pd.read_csv(f'../data/{EU_CORDIS_PROJECT_NAME}/files/csv/organization.csv', delimiter=';')
df_projects = pd.read_csv(f'../data/{EU_CORDIS_PROJECT_NAME}/files/csv/project.csv', delimiter=';')

# %%
display(df_organization.head(2))
print(df_organization.shape)
# Out:
#    projectID projectAcronym  organisationID vatNumber  \
# 0     217257     IMERA-PLUS     999559296.0       NaN
# 1     217246         BONUS+     999806646.0       NaN
#
#                                                 name   shortName  SME  \
# 0  EURAMET EV - EUROPEAN ASSOCIATION OF NATIONAL ...     EURAMET  NaN
# 1  BALTIC ORGANISATIONS NETWORK FOR FUNDING SCIEN...  BONUS EEIG  NaN
#
#   activityType             street postCode  ...  \
# 0          REC    Bundesallee 100    38116  ...
# 1          OTH  PASILANRAITIO 9 B    00240  ...
#
#                                          contactForm    contentUpdateDate  \
# 0  https://ec.europa.eu/info/funding-tenders/oppo...  2023-03-10 20:03:22
# 1  https://ec.europa.eu/info/funding-tenders/oppo...  2022-09-03 22:47:18
#
#        rcn order         role ecContribution netEcContribution totalCost  \
# 0  2267129     1  coordinator     21000000.0               NaN       NaN
# 1  2193825     1  coordinator     7266762.69               NaN       NaN
#
#    endOfParticipation active
# 0               False    NaN
# 1               False    NaN
#
# [2 rows x 25 columns]
# (123419, 25)

# %%
display(df_projects.head(2))
print(df_projects.shape)
# Out:
#        id     acronym  status  \
# 0  217257  IMERA-PLUS  CLOSED
# 1  217246      BONUS+  CLOSED
#
#                                                title   startDate     endDate  \
# 0  Implementing Metrology in the European Researc...  2007-06-01  2012-05-31
# 1  Multilateral call for research projects within...  2007-05-10  2012-05-09
#
#      totalCost ecMaxContribution legalBasis  topics  ecSignatureDate  \
# 0     64865124          21000000     FP7-GA  ERANET              NaN
# 1  22512219,96        7266762,69     FP7-GA  ERANET              NaN
#
#   frameworkProgramme  masterCall                  subCall fundingScheme  \
# 0                FP7         NaN  FP7-2007-ERANET-4.2.2.2  CSA-ERA-Plus
# 1                FP7         NaN  FP7-2007-ERANET-4.2.2.2  CSA-ERA-Plus
#
#   nature                                          objective  \
# 0    NaN  The central nerve in the spine of our high-tec...
# 1    NaN  BONUS EEIG - representing altogether 10 RTD or...
#
#      contentUpdateDate    rcn  grantDoi
# 0  2023-03-10 20:03:22  86251       NaN
# 1  2022-09-03 22:47:18  86250       NaN
# (21814, 20)

# %% [markdown]
# ## **MERGE DATA AND FILTER ON NL** <a class="anchor" id="3"></a>

# %%
# Here we merge projects and organizations to only keep the NL data.
# If any of the VAT numbers of the organization start with 'NL' then we keep the data.

# Group by projectID and aggregate vatNumber into lists
df_organization_grouped = df_organization.groupby('projectID')['vatNumber'].apply(list).reset_index()

# Merge df_projects with the grouped df_organization on the id and projectID columns
df_merged = pd.merge(df_projects, df_organization_grouped, how='left', left_on='id', right_on='projectID')

# Drop the redundant projectID column
df_merged = df_merged.drop(columns=['projectID'])

# Ensure vatNumber is treated as a list even if it is NaN
df_merged['vatNumber'] = df_merged['vatNumber'].apply(lambda x: x if isinstance(x, list) else [])

# Filter records where any of the values in vatNumber start with 'NL'
df_projects = df_merged[df_merged['vatNumber'].apply(lambda x: any(isinstance(v, str) and v.startswith('NL') for v in x))].reset_index()

display(df_projects.head(2))
print(df_projects.shape)
# Out:
#    index      id  acronym  status  \
# 0     16  601714  DIAGMAL  CLOSED
# 1     25  223226  PHARVAT  CLOSED
#
#                                                title   startDate     endDate  \
# 0  Translation of the direct-on-blood PCR-NALFIA ...  2013-09-01  2017-02-28
# 1  Platform for the Harmonization of Vaccine Adju...  2009-11-01  2011-10-31
#
#     totalCost ecMaxContribution  legalBasis  ... frameworkProgramme  \
# 0  3565749,11           2652374  FP7-HEALTH  ...                FP7
# 1   334018,16            300000  FP7-HEALTH  ...                FP7
#
#    masterCall                       subCall  fundingScheme nature  \
# 0         NaN  FP7-HEALTH-2013-INNOVATION-2          CP-FP    NaN
# 1         NaN             FP7-HEALTH-2007-B         CSA-SA    NaN
#
#                                            objective    contentUpdateDate  \
# 0  Accurate diagnosis of malaria is essential to ...  2019-08-02 11:04:44
# 1  Adjuvants are critical to the quality and magn...  2017-05-29 17:42:01
#
#       rcn grantDoi                                          vatNumber
# 0  108624      NaN  [NL002564476B01, FI23444528, nan, nan, NL00462...
# 1   92315      NaN                 [NL803597691B01, DE815127939, nan]
#
# [2 rows x 22 columns]
# (4010, 22)

# %%
# Replacing commas with periods in the 'ecMaxContribution' column
df_projects['ecMaxContribution'] = df_projects['ecMaxContribution'].str.replace(',', '.')

# Ensure the 'ecMaxContribution' column is numeric
df_projects['ecMaxContribution'] = pd.to_numeric(df_projects['ecMaxContribution'], errors='coerce')

# %%
# Only the year value from startDate will be used
df_projects['startDate'] = df_projects['startDate'].str.extract(r'(\d{4})')
df_projects['startDate'] = df_projects['startDate'] + '-01-01'
display(df_projects.head(2))
print(df_projects.shape)
# Out:
#    index      id  acronym  status  \
# 0     16  601714  DIAGMAL  CLOSED
# 1     25  223226  PHARVAT  CLOSED
#
#                                                title   startDate     endDate  \
# 0  Translation of the direct-on-blood PCR-NALFIA ...  2013-01-01  2017-02-28
# 1  Platform for the Harmonization of Vaccine Adju...  2009-01-01  2011-10-31
#
#     totalCost  ecMaxContribution  legalBasis  ... frameworkProgramme  \
# 0  3565749,11          2652374.0  FP7-HEALTH  ...                FP7
# 1   334018,16           300000.0  FP7-HEALTH  ...                FP7
#
#    masterCall                       subCall  fundingScheme nature  \
# 0         NaN  FP7-HEALTH-2013-INNOVATION-2          CP-FP    NaN
# 1         NaN             FP7-HEALTH-2007-B         CSA-SA    NaN
#
#                                            objective    contentUpdateDate  \
# 0  Accurate diagnosis of malaria is essential to ...  2019-08-02 11:04:44
# 1  Adjuvants are critical to the quality and magn...  2017-05-29 17:42:01
#
#       rcn grantDoi                                          vatNumber
# 0  108624      NaN  [NL002564476B01, FI23444528, nan, nan, NL00462...
# 1   92315      NaN                 [NL803597691B01, DE815127939, nan]
#
# [2 rows x 22 columns]
# (4010, 22)

# %% [markdown]
# ## **PREPROCESSING** <a class="anchor" id="4"></a>

# %%
# text column contains title and summary
df_projects['text'] = df_projects['title'] + ' ' + df_projects['objective']
df_projects['text'] = df_projects['text'].apply(lambda x: str(x) if not isinstance(x, str) else x)

# Function for preprocessing textual data (for BERT)
import re
def preprocess_text(text):
    # Lowercase the text and remove non-alphabetic characters
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)  # removing non-alphabetic characters
    # Use regex to keep only words
    text = ' '.join(re.findall(r'\b[a-z]+\b', text))
    return text

# Apply the preprocessing to both 'title' and 'summary_en'
df_projects['text'] = df_projects['text'].apply(preprocess_text)

# %%
display(df_projects.head(2))
print(df_projects.shape)
# Out:
#    index      id  acronym  status  \
# 0     16  601714  DIAGMAL  CLOSED
# 1     25  223226  PHARVAT  CLOSED
#
#                                                title   startDate     endDate  \
# 0  Translation of the direct-on-blood PCR-NALFIA ...  2013-01-01  2017-02-28
# 1  Platform for the Harmonization of Vaccine Adju...  2009-01-01  2011-10-31
#
#     totalCost  ecMaxContribution  legalBasis  ... masterCall  \
# 0  3565749,11          2652374.0  FP7-HEALTH  ...        NaN
# 1   334018,16           300000.0  FP7-HEALTH  ...        NaN
#
#                         subCall fundingScheme  nature  \
# 0  FP7-HEALTH-2013-INNOVATION-2         CP-FP     NaN
# 1             FP7-HEALTH-2007-B        CSA-SA     NaN
#
#                                            objective    contentUpdateDate  \
# 0  Accurate diagnosis of malaria is essential to ...  2019-08-02 11:04:44
# 1  Adjuvants are critical to the quality and magn...  2017-05-29 17:42:01
#
#       rcn grantDoi                                          vatNumber  \
# 0  108624      NaN  [NL002564476B01, FI23444528, nan, nan, NL00462...
# 1   92315      NaN                 [NL803597691B01, DE815127939, nan]
#
#                                                 text
# 0  translation of the directonblood pcrnalfia sys...
# 1  platform for the harmonization of vaccine adju...
#
# [2 rows x 23 columns]
# (4010, 23)

# %% [markdown]
# ## **EXPORT TO PKL** <a class="anchor" id="5"></a>

# %%
# Export data to pickle
df_projects.to_pickle(f"../data/{EU_CORDIS_PROJECT_NAME}_preprocessed.pkl")
